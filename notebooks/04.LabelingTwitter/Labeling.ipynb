# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa
from tqdm import tqdm
import os
from pprint import pprint
# Out:
# 2023-04-09 13:28:37.760383: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load Parquet
df_6label = pq.read_table('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_predictions_6kind.parquet').to_pandas()

# %%
df_6label.insert(17, 'MankindPredictions', None)

# %%
df_6label.drop('MankindPredictions', axis=1, inplace=True)

# %%
df_0 = df_6label[df_6label['Predictions'] == 0]
df_1 = df_6label[df_6label['Predictions'] == 1]
df_2 = df_6label[df_6label['Predictions'] == 2]
df_3 = df_6label[df_6label['Predictions'] == 3]
df_4 = df_6label[df_6label['Predictions'] == 4]
df_5 = df_6label[df_6label['Predictions'] == 5]

# %%
import fastparquet
fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction0.parquet', df_0, compression='GZIP')
fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction1.parquet', df_1, compression='GZIP')
fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction2.parquet', df_2, compression='GZIP')
fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction3.parquet', df_3, compression='GZIP')
fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction4.parquet', df_4, compression='GZIP')
fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction5.parquet', df_5, compression='GZIP')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 7
#       5 fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction3.parquet', df_3, compression='GZIP')
#       6 fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction4.parquet', df_4, compression='GZIP')
# ----> 7 fastparquet.write('/home/data/xuyijie/Documents/AllsidesScraper/news-title-bias/data/TwitterData/df_tweet_content_en_prediction5.parquet', df_5, compression='GZIP')
#
# ...

# %%
i = 0
print(df_0.TweetContent.iloc[i])
# Out:
# How exactly does the CDC know there’s going to be an outbreak of paralysis in children 5 and up this winter ? They’ve warned Dr’s and hospitals to call it AFM, but how do they know it’s coming ? 🤔

# %%
df_6label.MankindPredictions[i] = 0
# Out:
# /tmp/ipykernel_3393631/2447858472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6label.MankindPredictions[i] = 0

# %%
df_6label
# Out:
#                                                         URL  \
# 0         https://twitter.com/andya_d/status/15879267685...
# 1         https://twitter.com/andya_d/status/15875736234...
# 2         https://twitter.com/andya_d/status/15875189967...
# 3         https://twitter.com/andya_d/status/15874439853...
# 4         https://twitter.com/andya_d/status/15872511012...
# ...                                                     ...
# 69499255  https://twitter.com/fetz_mv/status/10394790615...
# 69499256  https://twitter.com/fetz_mv/status/10391362625...
# 69499257  https://twitter.com/fetz_mv/status/10374968680...
# 69499258  https://twitter.com/fetz_mv/status/10374732683...
# 69499259  https://twitter.com/fetz_mv/status/10369359412...
#
#                                Date                         User ReplyCount  \
# 0         2022-11-02 21:56:58+00:00  https://twitter.com/andya_d          1
# 1         2022-11-01 22:33:42+00:00  https://twitter.com/andya_d          1
# ...
